# %%
from platform import python_version

print(python_version())

# %% [markdown]
# # Lembre de substituir /caminho/ pelo seu diretorio de trabalho

# %% [markdown]
# # Esse script usa a versao python3.8

# %%
import pyautogui as gui
import time
import random
import sys

from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options
from selenium.webdriver import ActionChains
from time import sleep

# %%
#abre os contatos para o programa
entrada = "contatos"
entrada_2 = "contatos_enviados.txt"
entrada_3 = "comandos"

######pega os contatos ja enviados
dados1=open(entrada).readlines()
contatos=[]
for j in range(len(dados1)):
	line=dados1[j].rstrip()
	line=line.split(";;")
	if len(line[1]) <= 8:
		line_correct = "ok" 

	else:
		contato_formatado = line[1]
		contato_formatado = contato_formatado[-8:]
		line[1] = contato_formatado
	contatos.append(line)
	print(line)
tamanho = len(contatos)
print("numero de contatos: " + str(tamanho))	


######pega os contatos completo
dados2=open(entrada_2).readlines()
contatos_2=[]
for j in range(len(dados2)):
	line=dados2[j].rstrip()
	line=line.split(";;")
	if len(line[1]) <= 8:
		line_correct = "ok"
		

	else:
		contato_formatado = line[1]
		contato_formatado = contato_formatado[1:]
		line[1] = contato_formatado
	contatos_2.append(line)
	print(line)

tamanho = len(contatos_2)
print("numero de contatos_2: " + str(tamanho))

######abre os comandos a ser executado
	
dados3=open(entrada_3).readlines()

comandos=[]
for j in range(len(dados3)):
	comandos.append(dados3[j].replace("\n", "",))
	
for j in range(len(dados3)):
	print(comandos[j])

######compara as listas

if len(contatos_2) > len(contatos):
	lista_maior = contatos_2
	lista_menor = contatos
else:
	lista_maior = contatos
	lista_menor = contatos_2
	
lista_de_faltantes=[]
for i in range(len(lista_maior)):
	diferente = 0
	
	for j in range(len(lista_menor)):

		if lista_maior[i][1] == lista_menor[j][1]:
			diferente = 1
#			print(str(lista_maior[i][1]) +";;"+str(lista_menor[j][1]))
			
	if diferente == 0:		
		lista_de_faltantes.append(lista_maior[i])

for j in range(len(lista_de_faltantes)):

	print(lista_de_faltantes[j])		

print("numero de contatos para envio é igua: " + str(len(lista_de_faltantes)))

# %%
def abrir_contato(contato_cliente):
	contato_formatado = "a"
	acao_humana_min = 1
	acao_humana_max = 2
	if len(contato_cliente) <= 8:
		contato_formatado = contato_cliente 

	else:
		contato_formatado = contato_cliente[1:] 
#clica na barra para colocar o contato
	navegador.find_element_by_xpath('//*[@id="side"]/div[1]/div/div/div[2]/div/div[1]/p').click()
	time.sleep(random.randint(acao_humana_min, acao_humana_max))
#aperta ctr + a 
	navegador.find_element_by_xpath('//*[@id="side"]/div[1]/div/div/div[2]/div/div[1]/p').send_keys(Keys.CONTROL+"a")
#coloca o contato na barra para colocar o contato
	navegador.find_element_by_xpath('//*[@id="side"]/div[1]/div/div/div[2]/div/div[1]/p').send_keys(contato_formatado)
	time.sleep(random.randint(acao_humana_min, acao_humana_max))
#procura o contato na barra para colocar o contato
	navegador.find_element_by_xpath('//*[@id="side"]/div[1]/div/div/div[2]/div/div[1]/p').send_keys(Keys.ENTER)
	time.sleep(random.randint(acao_humana_min, acao_humana_max))


def mandar_mensagem(mensagem):
	tipo_mensagem = mensagem.split(".")
	tipo_midia = "a"
	acao_humana_min = 1
	acao_humana_max = 2

	midias = ["jpg", "png", "mp4", "jpeg", "avi", "flv", "mkv", "mov", "mp4", "webm", "wmv", "JPG", "PNG", "MP4", "JPEG", "AVI", "FLV", "MKV", "MOV", "MP4", "WEBM", "WMV"]
	arquivos = ["xlsx", "pdf", "doc", "docx", "XLSX", "PDF", "DOC", "DOCX"]
	espaco = ["enter"]
#acha o tipo de midia
	for j in range(len(tipo_mensagem)):
		if tipo_mensagem[j] in midias:
			tipo_midia = "midias"
		elif tipo_mensagem[j] in arquivos:
			tipo_midia = "arquivos"
		elif tipo_mensagem[j] in espaco:
			tipo_midia = "enter"
#manda a msg pelo tipo de midia
#midias "jpg", "png", "mp4", "jpeg", "avi", "flv", "mkv", "mov", "mp4", "webm", "wmv"
	if "." in mensagem and tipo_midia == "enter":
		navegador.find_element_by_xpath('//*[@id="main"]/footer/div[1]/div/span[2]/div/div[2]/div[1]').send_keys(Keys.ENTER)
		
	elif "/" in mensagem and tipo_midia == "midias":
		
#clica no clips
		navegador.find_element_by_xpath('//*[@id="main"]/footer/div[1]/div/span[2]/div/div[1]/div/div/div/div/span').click()
		time.sleep(random.randint(acao_humana_min, acao_humana_max))
#clica no tipo de arquivo a ser enviado
		ativo = navegador.find_element_by_css_selector('input[accept="image/*,video/mp4,video/3gpp,video/quicktime"]')
		time.sleep(random.randint(acao_humana_min, acao_humana_max))
#cola o caminho do arquivo
		ativo.send_keys(mensagem)
		time.sleep(random.randint(acao_humana_min, acao_humana_max))
#aperta para enviar
		while len(navegador.find_elements_by_xpath('//*[@id="wa-popovers-bucket"]')) < 1:
			time.sleep(1)
	
		time.sleep(2)
		navegador.find_element_by_xpath('//*[@id="app"]//div[@role="button"]/span[@data-icon="send"]').click()
		time.sleep(random.randint(acao_humana_min, acao_humana_max))

		
#arquivos pdf, xlsx

	elif "/" in mensagem and tipo_midia == "arquivos":
		navegador.find_element_by_xpath('//*[@id="main"]/footer/div[1]/div/span[2]/div/div[2]/div[1]').send_keys(Keys.ENTER)
#clica no clips
		navegador.find_element_by_xpath('//*[@id="main"]/footer/div[1]/div/span[2]/div/div[1]/div/div/div/div/span').click()
		time.sleep(random.randint(acao_humana_min, acao_humana_max))
#clica no tipo de arquivo a ser enviado
		ativo = navegador.find_element_by_css_selector("input[type='file']")
		time.sleep(random.randint(acao_humana_min, acao_humana_max))
#cola o caminho do arquivo
		ativo.send_keys(mensagem)
		time.sleep(random.randint(acao_humana_min, acao_humana_max))
#aperta para enviar
		while len(navegador.find_elements_by_xpath('//*[@id="wa-popovers-bucket"]')) < 1:
			time.sleep(1)
	
		time.sleep(2)
		navegador.find_element_by_xpath('//*[@id="app"]//div[@role="button"]/span[@data-icon="send"]').click()
		time.sleep(random.randint(acao_humana_min, acao_humana_max))
#mensagem comum
	else:
		navegador.find_element_by_xpath('//*[@id="main"]/footer/div[1]/div/span[2]/div/div[2]/div[1]').send_keys(mensagem)
		time.sleep(random.randint(1, 2))
		navegador.find_element_by_xpath('//*[@id="main"]/footer/div[1]/div/span[2]/div/div[2]/div[1]').send_keys(Keys.SHIFT+Keys.ENTER)
		time.sleep(random.randint(1, 2))

# %%
#Abre navegador
options = webdriver.ChromeOptions() 
options.add_argument("user-data-dir=/home/caminho/Executavel/Perfil")
#options.add_argument('/home/igor/Documentos/python/autowhats/Executavel/chromedriver')
options.add_argument("profile-directory=Profile 2")
navegador = webdriver.Chrome(executable_path="/home/caminho/chromedriver", options=options)
#navegador = webdriver.Chrome(options=options)
navegador.get("https://web.whatsapp.com/")


#navegador.get("https://web.whatsapp.com/")

#espera carregar
while len(navegador.find_elements_by_id("side")) < 1:
	time.sleep(1)
	
time.sleep(2)

# %%
#passo a passo do whats
numero_de_disparos = 0
disparos_aceitavel = 10

salvar_contato = open('contatos_enviados.txt', 'a')

for i in range(len(lista_de_faltantes)):

	while len(navegador.find_elements_by_id("side")) < 1:
		time.sleep(1)
	
	time.sleep(2)

	abrir_contato(lista_de_faltantes[i][1])
	
#manda as mensagens
	if  len(navegador.find_elements_by_xpath('//*[@id="pane-side"]/div/div/div/div[2]/div')) >= 1 or len(navegador.find_elements_by_xpath('//*[@id="pane-side"]/div/div/div/div[1]/div')) >= 1:
		for j in range(len(comandos)):
			mandar_mensagem(comandos[j])

		mensagem_enviada = 0
		while mensagem_enviada > 1:
			mensagem_enviada = len(navegador.find_elements_by_css_selector('[aria-label="Pendente"]'))
			time.sleep(1)
		navegador.find_element_by_xpath('//*[@id="main"]/footer/div[1]/div/span[2]/div/div[2]/div[1]').send_keys(Keys.ENTER)
		time.sleep(1)

#controla o numero de disparos
		numero_de_disparos = numero_de_disparos+1
		if numero_de_disparos > disparos_aceitavel:
			numero_de_disparos = 0
			disparos_aceitavel = random.randint(5, 12)
			time.sleep(random.randint(150, 300))
	
		salvar_contato.write(lista_de_faltantes[i][0]+";;"+lista_de_faltantes[i][1]+"\n")

salvar_contato.close()
navegador.quit()
